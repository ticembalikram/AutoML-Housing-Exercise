# %%
# Cell 1: Install Dependencies
# Run this cell first!
# !pip install h2o
# !pip install tpot
# !pip install mljar-supervised
# Out:
# Requirement already satisfied: h2o in /usr/local/lib/python3.12/dist-packages (3.46.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from h2o) (2.32.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from h2o) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->h2o) (2026.1.4)
# Requirement already satisfied: tpot in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from tpot) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from tpot) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from tpot) (1.6.1)
# Requirement already satisfied: update-checker>=0.16 in /usr/local/lib/python3.12/dist-packages (from tpot) (0.18.0)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.12/dist-packages (from tpot) (4.67.1)
# Requirement already satisfied: stopit>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from tpot) (1.1.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from tpot) (2.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from tpot) (1.5.3)
# Requirement already satisfied: xgboost>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from tpot) (3.1.2)
# Requirement already satisfied: matplotlib>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from tpot) (3.10.0)
# Requirement already satisfied: traitlets>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from tpot) (5.14.3)
# Requirement already satisfied: lightgbm>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from tpot) (4.6.0)
# Requirement already satisfied: optuna>=3.0.5 in /usr/local/lib/python3.12/dist-packages (from tpot) (4.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from tpot) (3.6.1)
# Requirement already satisfied: dask>=2024.4.2 in /usr/local/lib/python3.12/dist-packages (from tpot) (2025.12.0)
# Requirement already satisfied: distributed>=2024.4.2 in /usr/local/lib/python3.12/dist-packages (from tpot) (2025.12.0)
# Requirement already satisfied: dask-expr>=1.0.12 in /usr/local/lib/python3.12/dist-packages (from tpot) (2.0.0)
# Requirement already satisfied: dask-jobqueue>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from tpot) (0.9.0)
# Requirement already satisfied: func-timeout>=4.3.5 in /usr/local/lib/python3.12/dist-packages (from tpot) (4.3.5)
# Requirement already satisfied: configspace>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from tpot) (1.2.2)
# Requirement already satisfied: dill>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from tpot) (0.4.0)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from tpot) (0.13.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from configspace>=1.1.1->tpot) (3.3.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from configspace>=1.1.1->tpot) (4.15.0)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from configspace>=1.1.1->tpot) (10.8.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->tpot) (0.12.1)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (2.5.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->tpot) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->tpot) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->tpot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->tpot) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->tpot) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->tpot) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->tpot) (2.9.0.post0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.5->tpot) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.5->tpot) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.5->tpot) (2.0.45)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->tpot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->tpot) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->tpot) (3.6.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from update-checker>=0.16->tpot) (2.32.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost>=3.0.0->tpot) (2.29.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0.5->tpot) (1.3.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.3->distributed>=2024.4.2->tpot) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->tpot) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0.5->tpot) (3.3.0)
# Requirement already satisfied: mljar-supervised in /usr/local/lib/python3.12/dist-packages (1.1.18)
# Requirement already satisfied: numpy<2,>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (2.2.2)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (1.6.1)
# Requirement already satisfied: xgboost>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (3.1.2)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (4.6.0)
# Requirement already satisfied: catboost>=0.24.4 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (1.2.8)
# Requirement already satisfied: joblib>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (1.5.3)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (0.9.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (3.10.0)
# Requirement already satisfied: dtreeviz>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (2.3.2)
# Requirement already satisfied: shap>=0.42.1 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (0.49.1)
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (0.13.2)
# Requirement already satisfied: optuna-integration>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (4.6.0)
# Requirement already satisfied: mljar-scikit-plot>=0.3.11 in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (0.3.12)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (3.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (4.15.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from mljar-supervised) (7.34.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4->mljar-supervised) (0.21)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4->mljar-supervised) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4->mljar-supervised) (1.17.0)
# Requirement already satisfied: colour in /usr/local/lib/python3.12/dist-packages (from dtreeviz>=2.2.2->mljar-supervised) (0.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (2.9.0.post0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from optuna-integration>=3.6.0->mljar-supervised) (4.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mljar-supervised) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->mljar-supervised) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.0->mljar-supervised) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.1->mljar-supervised) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.1->mljar-supervised) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.1->mljar-supervised) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.42.1->mljar-supervised) (3.1.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost>=2.0.0->mljar-supervised) (2.29.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (5.14.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->mljar-supervised) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->mljar-supervised) (0.8.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.42.1->mljar-supervised) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->mljar-supervised) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->mljar-supervised) (0.2.14)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (2.0.45)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (6.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost>=0.24.4->mljar-supervised) (9.1.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->optuna-integration>=3.6.0->mljar-supervised) (1.3.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration>=3.6.0->mljar-supervised) (3.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna->optuna-integration>=3.6.0->mljar-supervised) (3.0.3)

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# 1. Load Data
housing = fetch_california_housing()
X_train, X_test, y_train, y_test = train_test_split(
    pd.DataFrame(housing.data, columns=housing.feature_names),
    pd.Series(housing.target, name='Price'),
    test_size=0.2,
    random_state=42
)
print("Data Loaded successfully.")
# Out:
# Data Loaded successfully.

# %%
import h2o
from h2o.automl import H2OAutoML

# Initialize H2O
h2o.init()

# Convert to H2O format
train_hf = h2o.H2OFrame(pd.concat([X_train, y_train], axis=1))
test_hf = h2o.H2OFrame(pd.concat([X_test, y_test], axis=1))

# Run AutoML
aml = H2OAutoML(max_models=5, max_runtime_secs=60, seed=42)
aml.train(y='Price', training_frame=train_hf)

# Results
lb = aml.leaderboard
print(lb.head(rows=lb.nrows))
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         1 hour 3 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.9
# H2O_cluster_version_age:    1 month and 20 days
# H2O_cluster_name:           H2O_from_python_unknownUser_uedgau
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.126 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.12.12 final
# --------------------------  -----------------------------------------------------------------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                rmse       mse       mae       rmsle    mean_residual_deviance
# GBM_1_AutoML_2_20260113_221356      0.460705  0.21225   0.304322    0.139069                  0.21225
# XGBoost_1_AutoML_2_20260113_221356  0.501019  0.25102   0.334594    0.153306                  0.25102
# XGBoost_2_AutoML_2_20260113_221356  0.508323  0.258392  0.342598    0.155179                  0.258392
# GLM_1_AutoML_2_20260113_221356      0.720958  0.519781  0.529129  nan                         0.519781
# [4 rows x 6 columns]

# %%
from tpot import TPOTRegressor
from sklearn.metrics import r2_score

tpot = TPOTRegressor(
    generations=1,
    population_size=5,
    max_time_mins=2,
    random_state=42
)
# Train on a smaller slice of data if needed
tpot.fit(X_train[:1000], y_train[:1000]) # Uses only first 1000 rows

# Get predictions from the best model
y_pred = tpot.predict(X_test)

# Calculate the R2 score
tpot_score = r2_score(y_test, y_pred)
print(f"TPOT R2 Score: {tpot_score}")
# Out:
# /usr/local/lib/python3.12/dist-packages/tpot/tpot_estimator/estimator.py:458: UserWarning: Both generations and max_time_mins are set. TPOT will terminate when the first condition is met.
# /usr/local/lib/python3.12/dist-packages/distributed/node.py:188: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39621 instead
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:35647
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:39621/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:34819'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:38785 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38785
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:41436
# INFO:distributed.scheduler:Receive client connection: Client-800f33c2-f0ce-11f0-837c-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:41448
# Generation: 100%|██████████| 1/1 [00:46<00:00, 46.84s/it]
# INFO:distributed.scheduler:Retire worker addresses (stimulus_id='retire-workers-1768343064.694578') (0,)
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:34819'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:41436; closing.
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:38785 name: 0 (stimulus_id='handle-worker-cleanup-1768343064.7073667')
# ERROR:distributed.scheduler:Removing worker 'tcp://127.0.0.1:38785' caused the cluster to lose scattered data, which can't be recovered: {'DataFrame-013e9543c0e9502f2559a1cb10e6614a', 'Series-23f5e8fd0039d615129b71ddd758f573'} (stimulus_id='handle-worker-cleanup-1768343064.7073667')
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:34819' closed.
# INFO:distributed.scheduler:Closing scheduler. Reason: unknown
# INFO:distributed.scheduler:Scheduler closing all comms
# TPOT R2 Score: 0.7319646004614612

# %%
# import autosklearn.regression
# import sklearn.metrics

# automl_askl = autosklearn.regression.AutoSklearnRegressor(time_left_for_this_task=120, per_run_time_limit=30)
# automl_askl.fit(X_train, y_train)
# y_pred = automl_askl.predict(X_test)
# print("Auto-sklearn R2 score:", sklearn.metrics.r2_score(y_test, y_pred))

# %%
from supervised.automl import AutoML

# Use mode="Explain" for fast results
automl_mljar = AutoML(mode="Explain")
automl_mljar.fit(X_train, y_train)
print("MLJAR R2 score:", automl_mljar.score(X_test, y_test))
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_2
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Baseline', 'Decision Tree', 'Random Forest', 'Xgboost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble']
# * Step simple_algorithms will try to check up to 2 models
# 1_Baseline rmse 1.159509 trained in 1.24 seconds
# 2_DecisionTree rmse 0.805325 trained in 3.17 seconds
# * Step default_algorithms will try to check up to 3 models
# 3_Default_Xgboost rmse 0.468276 trained in 8.39 seconds
# 4_Default_NeuralNetwork rmse 0.55069 trained in 2.32 seconds
# 5_Default_RandomForest rmse 0.729023 trained in 5.42 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 0.467368 trained in 0.28 seconds
# AutoML fit time: 29.19 seconds
# AutoML best model: Ensemble
# MLJAR R2 score: 0.8403741737876076
